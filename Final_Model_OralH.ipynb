# %%
# !pip install torch torchvision

# %%
from PIL import Image
from tensorflow.keras.preprocessing import image
import torch
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# %%
# Load your pretrained model
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/last.pt')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-8-27 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients
# Adding AutoShape...

# %%
# Path to your input image
image_path = '/content/fig-8-2a.jpg'
im = image.load_img(image_path,color_mode='rgb')
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x247>

# %%
# Perform object detection
results = model(image_path)
display(results)
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 247x406 1 Gingivitis
# Speed: 8.7ms pre-process, 259.8ms inference, 15.7ms NMS per image at shape (1, 3, 416, 640)

# %%
results.save('res_image.jpg')
# Out:
# Saved 1 image to runs/detect/exp3

# %%
output_image = "/content/runs/detect/exp3/fig-8-2a.jpg"
im = image.load_img(output_image,color_mode='rgb')
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x247>

# %%
print(results.crop())
# Out:
# Saved 1 image to runs/detect/exp2
# Saved results to runs/detect/exp2
# [{'box': [tensor(594.63776), tensor(77.32347), tensor(612.), tensor(158.11809)], 'conf': tensor(0.57969), 'cls': tensor(3.), 'label': 'Gingivitis 0.58', 'im': array([[[ 22,  33,  93],
#         [ 21,  32,  92],
#         [ 21,  32,  92],
#         ...,
#         [ 29, 178, 255],
#         [148, 219, 255],
#         [215, 241, 255]],
#
#        [[ 26,  37,  95],
#         [ 24,  35,  93],
#         [ 23,  34,  92],
#         ...,
#         [ 29, 178, 255],
#         [148, 219, 255],
#         [215, 241, 255]],
#
#        [[ 25,  36,  94],
#         [ 24,  35,  93],
#         [ 24,  35,  93],
#         ...,
#         [ 29, 178, 255],
#         [148, 219, 255],
#         [215, 241, 255]],
#
#        ...,
#
#        [[133, 172, 200],
#         [128, 167, 199],
#         [123, 165, 194],
#         ...,
#         [111, 151, 186],
#         [111, 151, 186],
#         [111, 151, 186]],
#
#        [[135, 172, 200],
# ...

# %%
results.names
# Out:
# {0: 'Caries', 1: 'Ulcer', 2: 'Tooth Discoloration', 3: 'Gingivitis'}

# %%
# Process detection results
for det in results.pred[0]:
    print(f"Confidence: {det[4]}")
# Out:
# Confidence: 0.8389711380004883
# Confidence: 0.8252359628677368
# Confidence: 0.819587230682373
# Confidence: 0.8129444122314453
# Confidence: 0.7936149835586548
# Confidence: 0.7792479991912842
# Confidence: 0.7640566229820251
# Confidence: 0.7566486597061157
# Confidence: 0.7524542212486267
# Confidence: 0.6573072075843811
# Confidence: 0.579688310623169
